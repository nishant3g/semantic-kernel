# %% [markdown]
# # Setup
#
# Import Semantic Kernel SDK from pypi.org

# %%
# Note: if using a virtual environment, do not run this cell
#%pip install -U semantic-kernel
from semantic_kernel import __version__

__version__
# Out:
# Collecting semantic-kernel
#   Obtaining dependency information for semantic-kernel from https://files.pythonhosted.org/packages/a8/11/e3d7c4cea310069bd5bbc0d352feb7b3323de2cc0c7bdff3dd1362cd0cde/semantic_kernel-1.28.1-py3-none-any.whl.metadata
#   Downloading semantic_kernel-1.28.1-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp~=3.8 (from semantic-kernel)
#   Obtaining dependency information for aiohttp~=3.8 from https://files.pythonhosted.org/packages/33/fb/41cde15fbe51365024550bf77b95a4fc84ef41365705c946da0421f0e1e0/aiohttp-3.11.16-cp312-cp312-win_amd64.whl.metadata
#   Downloading aiohttp-3.11.16-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting cloudevents~=1.0 (from semantic-kernel)
#   Obtaining dependency information for cloudevents~=1.0 from https://files.pythonhosted.org/packages/cf/0e/268a75b712e4dd504cff19e4b987942cd93532d1680009d6492c9d41bdac/cloudevents-1.11.0-py3-none-any.whl.metadata
#   Downloading cloudevents-1.11.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (2.9.2)
# Collecting pydantic-settings~=2.0 (from semantic-kernel)
#   Obtaining dependency information for pydantic-settings~=2.0 from https://files.pythonhosted.org/packages/b6/5f/d6d641b490fd3ec2c4c13b4244d68deea3a1b970a97be64f34fb5504ff72/pydantic_settings-2.9.1-py3-none-any.whl.metadata
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting defusedxml~=0.7 (from semantic-kernel)
#   Obtaining dependency information for defusedxml~=0.7 from https://files.pythonhosted.org/packages/07/6c/aa3f2f849e01cb6a001cd8554a88d4c77c5c1a31c95bdf1cf9301e6d9ef4/defusedxml-0.7.1-py2.py3-none-any.whl.metadata
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: azure-identity>=1.13 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (1.19.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (2.1.3)
# Collecting openai>=1.67 (from semantic-kernel)
#   Obtaining dependency information for openai>=1.67 from https://files.pythonhosted.org/packages/80/9a/f34f163294345f123673ed03e77c33dee2534f3ac1f9d18120384457304d/openai-1.75.0-py3-none-any.whl.metadata
#   Downloading openai-1.75.0-py3-none-any.whl.metadata (25 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel)
#   Obtaining dependency information for openapi_core<0.20,>=0.18 from https://files.pythonhosted.org/packages/27/6f/83ead0e2e30a90445ee4fc0135f43741aebc30cca5b43f20968b603e30b6/openapi_core-0.19.5-py3-none-any.whl.metadata
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websockets<16,>=13 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (14.1)
# Collecting aiortc>=1.9.0 (from semantic-kernel)
#   Obtaining dependency information for aiortc>=1.9.0 from https://files.pythonhosted.org/packages/b2/ce/7f969694b950f673d7bf5ec697608366bd585ff741760e107e3eff55b131/aiortc-1.11.0-cp39-abi3-win_amd64.whl.metadata
#   Downloading aiortc-1.11.0-cp39-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (1.27.0)
# Collecting prance~=23.6.21.0 (from semantic-kernel)
#   Obtaining dependency information for prance~=23.6.21.0 from https://files.pythonhosted.org/packages/c9/db/4fb4901ee61274d0ab97746461fc5f2637e5d73aa73f34ee28e941a699a1/prance-23.6.21.0-py3-none-any.whl.metadata
#   Downloading prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: jinja2~=3.1 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio~=1.6 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from semantic-kernel) (1.6.0)
# Collecting scipy>=1.15.1 (from semantic-kernel)
#   Obtaining dependency information for scipy>=1.15.1 from https://files.pythonhosted.org/packages/f5/6f/e6e5aff77ea2a48dd96808bb51d7450875af154ee7cbe72188afb0b37929/scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 660.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 463.5 kB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for aiohappyeyeballs>=2.3.0 from https://files.pythonhosted.org/packages/0f/15/5bf3b99495fb160b63f95972b81750f18f7f4e02ad051373b669d17d44f2/aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for aiosignal>=1.1.2 from https://files.pythonhosted.org/packages/ec/6a/bc7e17a3e87a2985d3e8f4da4cd0f481060eb78fb08596c42be62c90a4d9/aiosignal-1.3.2-py2.py3-none-any.whl.metadata
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for attrs>=17.3.0 from https://files.pythonhosted.org/packages/77/06/bb80f5f86020c4551da315d78b3ab75e8228f89f0162f2c3a819e407941a/attrs-25.3.0-py3-none-any.whl.metadata
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/80/2e/fb4ed62a65f8cd66044706b1013f0010930d8cbb0729a2219561ea075434/frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for multidict<7.0,>=4.5 from https://files.pythonhosted.org/packages/06/24/c8fdff4f924d37225dc0c56a28b1dca10728fc2233065fafeb27b4b125be/multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for propcache>=0.2.0 from https://files.pythonhosted.org/packages/24/bb/3b1b01da5dd04c77a204c84e538ff11f624e31431cfde7201d9110b092b1/propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.8->semantic-kernel)
#   Obtaining dependency information for yarl<2.0,>=1.17.0 from https://files.pythonhosted.org/packages/ca/c6/333fe0338305c0ac1c16d5aa7cc4841208d3252bbe62172e0051006b5445/yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
#      ---------------------------------------- 0.0/74.8 kB ? eta -:--:--
#      --------------- ---------------------- 30.7/74.8 kB 640.0 kB/s eta 0:00:01
#      ------------------------------------ - 71.7/74.8 kB 787.7 kB/s eta 0:00:01
#      -------------------------------------- 74.8/74.8 kB 686.5 kB/s eta 0:00:00
# Collecting aioice<1.0.0,>=0.9.0 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for aioice<1.0.0,>=0.9.0 from https://files.pythonhosted.org/packages/3b/58/af07dda649c22a1ae954ffb7aaaf4d4a57f1bf00ebdf62307affc0b8552f/aioice-0.10.1-py3-none-any.whl.metadata
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<15.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for av<15.0.0,>=14.0.0 from https://files.pythonhosted.org/packages/84/7d/ed088731274746667e18951cc51d4e054bec941898b853e211df84d47745/av-14.3.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading av-14.3.0-cp312-cp312-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: cffi>=1.0.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.17.1)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for cryptography>=44.0.0 from https://files.pythonhosted.org/packages/33/cf/1f7649b8b9a3543e042d3f348e398a061923ac05b507f3f4d95f11938aa9/cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting google-crc32c>=1.1 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for google-crc32c>=1.1 from https://files.pythonhosted.org/packages/0f/d6/77060dbd140c624e42ae3ece3df53b9d811000729a5c821b9fd671ceaac6/google_crc32c-1.7.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading google_crc32c-1.7.1-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for pyee>=13.0.0 from https://files.pythonhosted.org/packages/9b/4d/b9add7c84060d4c1906abe9a7e5359f2a60f7a9a4f67268b2766673427d8/pyee-13.0.0-py3-none-any.whl.metadata
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for pylibsrtp>=0.10.0 from https://files.pythonhosted.org/packages/9b/26/3a20b638a3a3995368f856eeb10701dd6c0e9ace9fb6665eeb1b95ccce19/pylibsrtp-0.12.0-cp39-abi3-win_amd64.whl.metadata
#   Downloading pylibsrtp-0.12.0-cp39-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for pyopenssl>=25.0.0 from https://files.pythonhosted.org/packages/ca/d7/eb76863d2060dcbe7c7e6cccfd95ac02ea0b9acc37745a0d99ff6457aefb/pyOpenSSL-25.0.0-py3-none-any.whl.metadata
#   Downloading pyOpenSSL-25.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: azure-core>=1.31.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.32.0)
# Requirement already satisfied: msal>=1.30.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (4.12.2)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel)
#   Obtaining dependency information for deprecation<3.0,>=2.0 from https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl.metadata
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from jinja2~=3.1->semantic-kernel) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openai>=1.67->semantic-kernel) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openai>=1.67->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openai>=1.67->semantic-kernel) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openai>=1.67->semantic-kernel) (0.7.1)
# Requirement already satisfied: sniffio in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openai>=1.67->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openai>=1.67->semantic-kernel) (4.67.0)
# Requirement already satisfied: isodate in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Collecting jsonschema<5.0.0,>=4.18.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for jsonschema<5.0.0,>=4.18.0 from https://files.pythonhosted.org/packages/69/4a/4f9dbeb84e8850557c02365a0eee0649abe5eb1d84af92a25731c6c0f922/jsonschema-4.23.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for jsonschema-path<0.4.0,>=0.3.1 from https://files.pythonhosted.org/packages/cb/58/3485da8cb93d2f393bce453adeef16896751f14ba3e2024bc21dc9597646/jsonschema_path-0.3.4-py3-none-any.whl.metadata
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/23/62/0fe302c6d1be1c777cab0616e6302478251dfbf9055ad426f5d0def75c89/more_itertools-10.6.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for openapi-schema-validator<0.7.0,>=0.6.0 from https://files.pythonhosted.org/packages/21/c6/ad0fba32775ae749016829dace42ed80f4407b171da41313d1a3a5f102e4/openapi_schema_validator-0.6.3-py3-none-any.whl.metadata
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for openapi-spec-validator<0.8.0,>=0.7.1 from https://files.pythonhosted.org/packages/2b/4d/e744fff95aaf3aeafc968d5ba7297c8cda0d1ecb8e3acd21b25adae4d835/openapi_spec_validator-0.7.1-py3-none-any.whl.metadata
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for parse from https://files.pythonhosted.org/packages/d0/31/ba45bf0b2aa7898d81cbbfac0e88c267befb59ad91a19e36e1bc5578ddb1/parse-1.20.2-py2.py3-none-any.whl.metadata
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for werkzeug<3.1.2 from https://files.pythonhosted.org/packages/ee/ea/c67e1dee1ba208ed22c06d1d547ae5e293374bfc43e0eb0ef5e262b68561/werkzeug-3.1.1-py3-none-any.whl.metadata
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: deprecated>=1.2.6 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.4.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.48b0)
# Collecting chardet>=3.0 (from prance~=23.6.21.0->semantic-kernel)
#   Obtaining dependency information for chardet>=3.0 from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance~=23.6.21.0->semantic-kernel)
#   Obtaining dependency information for ruamel.yaml>=0.17.10 from https://files.pythonhosted.org/packages/c2/36/dfc1ebc0081e6d39924a2cc53654497f967a084a436bb64402dfce4254d9/ruamel.yaml-0.18.10-py3-none-any.whl.metadata
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests>=2.25 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (2.32.3)
# Requirement already satisfied: six~=1.15 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (24.2)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: annotated-types>=0.6.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from pydantic-settings~=2.0->semantic-kernel) (1.0.1)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings~=2.0->semantic-kernel)
#   Obtaining dependency information for typing-inspection>=0.4.0 from https://files.pythonhosted.org/packages/31/08/aa4fdfb71f7de5176385bd9e90852eaf6b5d622735020ad600f2bab54385/typing_inspection-0.4.0-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: dnspython>=2.0.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel) (2.6.1)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel)
#   Obtaining dependency information for ifaddr>=0.2.0 from https://files.pythonhosted.org/packages/9c/1f/19ebc343cc71a7ffa78f17018535adc5cbdd87afb31d7c34874680148b32/ifaddr-0.2.0-py3-none-any.whl.metadata
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.67->semantic-kernel) (3.10)
# Requirement already satisfied: pycparser in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel) (1.16.0)
# Requirement already satisfied: certifi in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.21.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/d1/0f/8910b19ac0670a0f80ce1008e5e751c4a57e14d2c4c13a482aa6079fa9d6/jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/c1/b1/3baf80dc6d2b7bc27a95a67752d0208e410351e3feb4eb78de5f77454d8d/referencing-0.36.2-py3-none-any.whl.metadata
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/bb/46/b8b5424d1d21f2f2f3f2d468660085318d4f74a8df8289e3dd6ad224d488/rpds_py-0.24.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading rpds_py-0.24.0-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: PyYAML>=5.1 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.2)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for pathable<0.5.0,>=0.4.1 from https://files.pythonhosted.org/packages/7d/eb/b6260b31b1a96386c0a880edebe26f89669098acea8e0318bff6adb378fd/pathable-0.4.4-py3-none-any.whl.metadata
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.10.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from msal-extensions>=1.2.0->azure-identity>=1.13->semantic-kernel) (2.10.1)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for rfc3339-validator from https://files.pythonhosted.org/packages/7b/44/4e421b96b67b2daff264473f7465db72fbdf36a07e05494f50300cc7b0c6/rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Obtaining dependency information for lazy-object-proxy<2.0.0,>=1.7.1 from https://files.pythonhosted.org/packages/de/0c/645a881f5f27952a02f24584d96f9f326748be06ded2cee25f8f8d1cd196/lazy_object_proxy-1.11.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading lazy_object_proxy-1.11.0-cp312-cp312-win_amd64.whl.metadata (8.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (2.2.3)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.10->prance~=23.6.21.0->semantic-kernel)
#   Obtaining dependency information for ruamel.yaml.clib>=0.2.7 from https://files.pythonhosted.org/packages/d7/8f/c3654f6f1ddb75daf3922c3d8fc6005b1ab56671ad56ffb874d908bfa668/ruamel.yaml.clib-0.2.12-cp312-cp312-win_amd64.whl.metadata
#   Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: colorama in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from tqdm>4->openai>=1.67->semantic-kernel) (0.4.6)
# Requirement already satisfied: pywin32>=226 in c:\momentumcoderepo\mogenaiapirepo\.pocchatbot\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity>=1.13->semantic-kernel) (308)
# Downloading semantic_kernel-1.28.1-py3-none-any.whl (809 kB)
#    ---------------------------------------- 0.0/809.6 kB ? eta -:--:--
#    - -------------------------------------- 30.7/809.6 kB 1.3 MB/s eta 0:00:01
6 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.6/27.5 MB 3.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.7/27.5 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.8/27.5 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.0/27.5 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.2/27.5 MB 3.6 MB/s eta 0:00:05
#    ------------------ --------------------- 12.5/27.5 MB 3.7 MB/s eta 0:00:05
#    ------------------ --------------------- 12.7/27.5 MB 3.7 MB/s eta 0:00:05
#    ------------------ --------------------- 12.8/27.5 MB 3.7 MB/s eta 0:00:04
#    ------------------ --------------------- 13.0/27.5 MB 3.7 MB/s eta 0:00:04
#    ------------------- -------------------- 13.1/27.5 MB 3.7 MB/s eta 0:00:04
#    ------------------- -------------------- 13.3/27.5 MB 3.7 MB/s eta 0:00:04
#    ------------------- -------------------- 13.5/27.5 MB 3.7 MB/s eta 0:00:04
#    -------------------- ------------------- 13.7/27.5 MB 3.7 MB/s eta 0:00:04
#    -------------------- ------------------- 13.9/27.5 MB 3.8 MB/s eta 0:00:04
#    -------------------- ------------------- 14.1/27.5 MB 3.8 MB/s eta 0:00:04
#    -------------------- ------------------- 14.3/27.5 MB 3.8 MB/s eta 0:00:04
#    --------------------- ------------------ 14.4/27.5 MB 3.8 MB/s eta 0:00:04
#    --------------------- ------------------ 14.7/27.5 MB 3.7 MB/s eta 0:00:04
#    --------------------- ------------------ 14.9/27.5 MB 3.7 MB/s eta 0:00:04
#    --------------------- ------------------ 15.1/27.5 MB 3.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.3/27.5 MB 3.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.5/27.5 MB 3.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.7/27.5 MB 3.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.9/27.5 MB 3.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.0/27.5 MB 3.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 16.2/27.5 MB 3.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 16.4/27.5 MB 3.8 MB/s eta 0:00:03
#    ------------------------ --------------- 16.6/27.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------ --------------- 16.8/27.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------ --------------- 17.0/27.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.2/27.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.4/27.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.6/27.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.7/27.5 MB 3.9 MB/s eta 0:00:03
#    -------------------------- ------------- 18.0/27.5 MB 4.0 MB/s eta 0:00:03
#    -------------------------- ------------- 18.2/27.5 MB 4.0 MB/s eta 0:00:03
#    -------------------------- ------------- 18.4/27.5 MB 4.0 MB/s eta 0:00:03
#    --------------------------- ------------ 18.6/27.5 MB 4.0 MB/s eta 0:00:03
#    --------------------------- ------------ 18.8/27.5 MB 4.0 MB/s eta 0:00:03
#    --------------------------- ------------ 19.0/27.5 MB 4.0 MB/s eta 0:00:03
#    --------------------------- ------------ 19.2/27.5 MB 4.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.3/27.5 MB 4.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.6/27.5 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.8/27.5 MB 4.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.0/27.5 MB 4.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.3/27.5 MB 4.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.5/27.5 MB 4.1 MB/s eta 0:00:02
#    ------------------------------ --------- 20.7/27.5 MB 4.1 MB/s eta 0:00:02
#    ------------------------------ --------- 20.8/27.5 MB 4.1 MB/s eta 0:00:02
#    ------------------------------ --------- 21.0/27.5 MB 4.1 MB/s eta 0:00:02
#    ------------------------------ --------- 21.2/27.5 MB 4.2 MB/s eta 0:00:02
#    ------------------------------- -------- 21.4/27.5 MB 4.2 MB/s eta 0:00:02
#    ------------------------------- -------- 21.7/27.5 MB 4.2 MB/s eta 0:00:02
#    ------------------------------- -------- 22.0/27.5 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 22.2/27.5 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 22.3/27.5 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 22.5/27.5 MB 4.3 MB/s eta 0:00:02
#    --------------------------------- ------ 22.7/27.5 MB 4.3 MB/s eta 0:00:02
#    --------------------------------- ------ 23.0/27.5 MB 4.3 MB/s eta 0:00:02
#    --------------------------------- ------ 23.2/27.5 MB 4.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.4/27.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 23.7/27.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 23.9/27.5 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.1/27.5 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.2/27.5 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.5/27.5 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 24.8/27.5 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 25.0/27.5 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 25.2/27.5 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 25.5/27.5 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 25.7/27.5 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 25.9/27.5 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 26.1/27.5 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 26.4/27.5 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 26.6/27.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  26.8/27.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  27.1/27.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  27.5/27.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  27.5/27.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  27.5/27.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 27.5/27.5 MB 4.3 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    ---------------------------------------- 199.4/199.4 kB 4.0 MB/s eta 0:00:00
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB 7.9 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/3.2 MB 6.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/3.2 MB 6.6 MB/s eta 0:00:01
#    -------------- ------------------------- 1.1/3.2 MB 6.5 MB/s eta 0:00:01
#    --------------- ------------------------ 1.2/3.2 MB 6.6 MB/s eta 0:00:01
#    -------------------- ------------------- 1.7/3.2 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.9/3.2 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.9/3.2 MB 4.5 MB/s eta 0:00:01
#    ------------------------ --------------- 2.0/3.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.0/3.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  3.2/3.2 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  3.2/3.2 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 4.5 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl (120 kB)
#    ---------------------------------------- 0.0/120.5 kB ? eta -:--:--
#    ---------------------------------------- 120.5/120.5 kB 7.4 MB/s eta 0:00:00
# Downloading google_crc32c-1.7.1-cp312-cp312-win_amd64.whl (33 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.5 kB ? eta -:--:--
#    ---------------------------------------- 88.5/88.5 kB 4.9 MB/s eta 0:00:00
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl (38 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    ---------------------------------------- 44.8/44.8 kB 2.3 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.12.0-cp39-abi3-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB 5.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.5 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.5 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.5 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.6 MB/s eta 0:00:00
# Downloading pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.5 kB ? eta -:--:--
#    ---------------------------------------- 56.5/56.5 kB 2.9 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.7 kB ? eta -:--:--
#    ---------------------------------------- 117.7/117.7 kB 6.7 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
#    ---------------------------------------- 0.0/224.4 kB ? eta -:--:--
#    ---------------------------------------- 224.4/224.4 kB 6.9 MB/s eta 0:00:00
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
#    ---------------------------------------- 0.0/92.9 kB ? eta -:--:--
#    ---------------------------------------- 92.9/92.9 kB 5.5 MB/s eta 0:00:00
# Downloading more_itertools-10.6.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.0 kB ? eta -:--:--
#    ---------------------------------------- 63.0/63.0 kB 3.5 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading lazy_object_proxy-1.11.0-cp312-cp312-win_amd64.whl (28 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.24.0-cp312-cp312-win_amd64.whl (239 kB)
#    ---------------------------------------- 0.0/239.7 kB ? eta -:--:--
#    --------------------------------------  235.5/239.7 kB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 239.7/239.7 kB 7.4 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-win_amd64.whl (115 kB)
#    ---------------------------------------- 0.0/115.5 kB ? eta -:--:--
#    ---------------------------------------- 115.5/115.5 kB 6.6 MB/s eta 0:00:00
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (pyproject.toml): started
#   Building wheel for pybars4 (pyproject.toml): finished with status 'done'
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14429 sha256=f0b25b587b537bb8c2c77aed4a966da51bd6703859807110d0ae0c2dbf2a00e7
#   Stored in directory: c:\users\nishant.w.gupta\appdata\local\pip\cache\wheels\75\2d\da\c75b2fc7b00dc9c154dff65f689a318e7d24b44c612c2b21f1
#   Building wheel for PyMeta3 (pyproject.toml): started
#   Building wheel for PyMeta3 (pyproject.toml): finished with status 'done'
#   Created wheel for PyMeta3: filename=pymeta3-0.5.1-py3-none-any.whl size=16557 sha256=412ebd6b9b91e4686722c04e673bf1a7a765977ea577ebf6bcf506386d7cbee6
#   Stored in directory: c:\users\nishant.w.gupta\appdata\local\pip\cache\wheels\5a\9b\2c\81b7551d2c05a482817e6c3b3d2f8ad2a0229db874c4bc6346
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, ifaddr, werkzeug, typing-inspection, scipy, ruamel.yaml.clib, rpds-py, rfc3339-validator, pyee, pybars4, propcache, pathable, multidict, more-itertools, lazy-object-proxy, google-crc32c, frozenlist, deprecation, defusedxml, chardet, av, attrs, aioice, aiohappyeyeballs, yarl, ruamel.yaml, referencing, pylibsrtp, cryptography, cloudevents, aiosignal, pyopenssl, pydantic-settings, prance, openai, jsonschema-specifications, jsonschema-path, aiohttp, jsonschema, aiortc, openapi-schema-validator, openapi-spec-validator, openapi_core, semantic-kernel
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: openai
#     Found existing installation: openai 1.54.4
#     Uninstalling openai-1.54.4:
#       Successfully uninstalled openai-1.54.4
# Successfully installed PyMeta3-0.5.1 aiohappyeyeballs-2.6.1 aiohttp-3.11.16 aioice-0.10.1 aiortc-1.11.0 aiosignal-1.3.2 attrs-25.3.0 av-14.3.0 chardet-5.2.0 cloudevents-1.11.0 cryptography-44.0.2 defusedxml-0.7.1 deprecation-2.1.0 frozenlist-1.6.0 google-crc32c-1.7.1 ifaddr-0.2.0 jsonschema-4.23.0 jsonschema-path-0.3.4 jsonschema-specifications-2024.10.1 lazy-object-proxy-1.11.0 more-itertools-10.6.0 multidict-6.4.3 openai-1.75.0 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.1 openapi_core-0.19.5 parse-1.20.2 pathable-0.4.4 prance-23.6.21.0 propcache-0.3.1 pybars4-0.9.13 pydantic-settings-2.9.1 pyee-13.0.0 pylibsrtp-0.12.0 pyopenssl-25.0.0 referencing-0.36.2 rfc3339-validator-0.1.4 rpds-py-0.24.0 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 scipy-1.15.2 semantic-kernel-1.28.1 typing-inspection-0.4.0 werkzeug-3.1.1 yarl-1.20.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# '1.28.1'

# %% [markdown]
# Initial configuration for the notebook to run properly.

# %%
# Make sure paths are correct for the imports

import os
import sys

notebook_dir = os.path.abspath("")
parent_dir = os.path.dirname(notebook_dir)
grandparent_dir = os.path.dirname(parent_dir)


sys.path.append(grandparent_dir)

# %% [markdown]
# ### Configuring the Kernel
#
# Let's get started with the necessary configuration to run Semantic Kernel. For Notebooks, we require a `.env` file with the proper settings for the model you use. Create a new file named `.env` and place it in this directory. Copy the contents of the `.env.example` file from this directory and paste it into the `.env` file that you just created.
#
# **NOTE: Please make sure to include `GLOBAL_LLM_SERVICE` set to either OpenAI, AzureOpenAI, or HuggingFace in your .env file. If this setting is not included, the Service will default to AzureOpenAI.**
#
# #### Option 1: using OpenAI
#
# Add your [OpenAI Key](https://openai.com/product/) key to your `.env` file (org Id only if you have multiple orgs):
#
# ```
# GLOBAL_LLM_SERVICE="OpenAI"
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# OPENAI_CHAT_MODEL_ID=""
# OPENAI_TEXT_MODEL_ID=""
# OPENAI_EMBEDDING_MODEL_ID=""
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# #### Option 2: using Azure OpenAI
#
# Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to the `.env` file in the same folder:
#
# ```
# GLOBAL_LLM_SERVICE="AzureOpenAI"
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_CHAT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_TEXT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_API_VERSION="..."
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# For more advanced configuration, please follow the steps outlined in the [setup guide](./CONFIGURING_THE_KERNEL.md).

# %% [markdown]
# Let's define our kernel for this example.

# %%
from semantic_kernel import Kernel

kernel = Kernel()

# %% [markdown]
# We will load our settings and get the LLM service to use for the notebook.

# %%
from services import Service

from samples.service_settings import ServiceSettings

service_settings = ServiceSettings()

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = (
    Service.AzureOpenAI
    if service_settings.global_llm_service is None
    else Service(service_settings.global_llm_service.lower())
)
print(f"Using service type: {selectedService}")
# Out:
# Using service type: Service.AzureOpenAI

# %% [markdown]
# We now configure our Chat Completion service on the kernel.

# %%
# Remove all services so that this cell can be re-run without restarting the kernel
kernel.remove_all_services()

service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
        ),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
        ),
    )

# %% [markdown]
# # Run a Semantic Function
#
# **Step 3**: Load a Plugin and run a semantic function:

# %%
plugin = kernel.add_plugin(parent_directory="../../../prompt_template_samples/", plugin_name="FunPlugin")

# %%
from semantic_kernel.functions import KernelArguments

joke_function = plugin["Joke"]

joke = await kernel.invoke(
    joke_function,
    KernelArguments(input="time travel to dinosaur age", style="super silly"),
)
print(joke)
# Out:
# Why did the time traveler bring a ladder to the dinosaur age?
#
# Because he heard the dinosaurs were a little "over his head"!
